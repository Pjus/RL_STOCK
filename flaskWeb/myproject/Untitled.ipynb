# %%
import json
from http.client import HTTPSConnection
import requests

# %%
apikey = "7OVAOOPNIMKJKIAX"
symbol = "AAPL"
requestURL = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol="+ symbol +"&apikey=" + apikey;

# %%
res = requests.get(requestURL)

# %%
res
# Out:
# <Response [200]>

# %%
data = res.json()['Time Series (Daily)']

# %%
for i in data:
    print(data[i])
# Out:
# {'1. open': '441.6200', '2. high': '457.6500', '3. low': '439.1900', '4. close': '455.6100', '5. volume': '50607225'}
# {'1. open': '437.5100', '2. high': '441.5700', '3. low': '435.5900', '4. close': '440.2500', '5. volume': '30497988'}
# {'1. open': '436.5300', '2. high': '443.1600', '3. low': '433.5500', '4. close': '438.6600', '5. volume': '43198092'}
# {'1. open': '432.8000', '2. high': '446.5457', '3. low': '431.5700', '4. close': '435.7500', '5. volume': '77037847'}
# {'1. open': '411.5350', '2. high': '425.6600', '3. low': '403.3000', '4. close': '425.0400', '5. volume': '93573867'}
# {'1. open': '376.7500', '2. high': '385.1900', '3. low': '375.0700', '4. close': '384.7600', '5. volume': '39532505'}
# {'1. open': '375.0000', '2. high': '380.9200', '3. low': '374.8500', '4. close': '380.1600', '5. volume': '22582314'}
# {'1. open': '377.4700', '2. high': '378.1986', '3. low': '372.9900', '4. close': '373.0100', '5. volume': '25906375'}
# ...
